# %%
import pandas as pd
import re
import numpy as np
import torch 
import torch.nn as nn
import pickle
import pandas as pd
import matplotlib.pyplot as plt
from collections.abc import Iterable, Iterator
from torch.utils.data import DataLoader,Dataset
from torch.nn.utils import clip_grad_norm_
from tqdm import tqdm
import random
from torch.utils.tensorboard import SummaryWriter
from torch.nn.utils.rnn import pad_sequence

# %% [markdown]
# ### 数据处理
#
# – 编码数据、解码数据字典构建
# – Dataload数据后处理方法
#
# ### 模型结构
#
# – Encoder: embedding + rnn
# – Decoder: embedding + rnn + Linear
# – Encoder和Decoder衔接
# – Encoder采样方向：双向RNN
#
# ### 模型训练
#
# ### 生成推理

# %%
# 读取并拆分数据
def read_data(data_file):
    with open(data_file, "r") as f:
        lines = f.readlines()
        enc_data, dec_data = [], []
        for line in lines:
            if line == "":
                continue
            enc, dec = line.split("\t")
            enc_tokens = re.findall(r"[\w']+", enc)
            dec_tokens = ["<BOS>"] + re.findall(r"[\u4e00-\u9fff]", dec) + ["<EOS>"]
            enc_data.append(enc_tokens)
            dec_data.append(dec_tokens)

    assert len(enc_data) == len(dec_data), "编码数据和解码数据长度不一致。"
    return enc_data, dec_data

# %%
enc_data, dec_data = read_data("../../data/cmn.txt")
print(len(enc_data))
print(len(dec_data))
# Out:
# 20133
# 20133

# %%
dec_data
# Out:
# [['<BOS>', '嗨', '<EOS>'],
#  ['<BOS>', '你', '好', '<EOS>'],
#  ['<BOS>', '你', '用', '跑', '的', '<EOS>'],
#  ['<BOS>', '等', '等', '<EOS>'],
#  ['<BOS>', '你', '好', '<EOS>'],
#  ['<BOS>', '让', '我', '来', '<EOS>'],
#  ['<BOS>', '我', '赢', '了', '<EOS>'],
#  ['<BOS>', '不', '会', '吧', '<EOS>'],
#  ['<BOS>', '乾', '杯', '<EOS>'],
#  ['<BOS>', '他', '跑', '了', '<EOS>'],
#  ['<BOS>', '跳', '进', '来', '<EOS>'],
#  ['<BOS>', '我', '迷', '失', '了', '<EOS>'],
#  ['<BOS>', '我', '退', '出', '<EOS>'],
#  ['<BOS>', '我', '沒', '事', '<EOS>'],
#  ['<BOS>', '听', '着', '<EOS>'],
#  ['<BOS>', '不', '可', '能', '<EOS>'],
#  ['<BOS>', '没', '门', '<EOS>'],
#  ['<BOS>', '你', '确', '定', '<EOS>'],
#  ['<BOS>', '试', '试', '吧', '<EOS>'],
#  ['<BOS>', '我', '们', '来', '试', '试', '<EOS>'],
#  ['<BOS>', '为', '什', '么', '是', '我', '<EOS>'],
#  ['<BOS>', '去', '问', '汤', '姆', '<EOS>'],
#  ['<BOS>', '冷', '静', '点', '<EOS>'],
#  ['<BOS>', '公', '平', '点', '<EOS>'],
#  ['<BOS>', '友', '善', '点', '<EOS>'],
#  ['<BOS>', '和', '气', '点', '<EOS>'],
#  ['<BOS>', '联', '系', '我', '<EOS>'],
#  ['<BOS>', '联', '系', '我', '们', '<EOS>'],
#  ['<BOS>', '进', '来', '<EOS>'],
#  ['<BOS>', '找', '到', '汤', '姆', '<EOS>'],
#  ['<BOS>', '滾', '出', '去', '<EOS>'],
#  ['<BOS>', '走', '開', '<EOS>'],
#  ['<BOS>', '滾', '<EOS>'],
#  ['<BOS>', '走', '開', '<EOS>'],
#  ['<BOS>', '再', '见', '<EOS>'],
#  ['<BOS>', '告', '辞', '<EOS>'],
#  ['<BOS>', '等', '一', '下', '<EOS>'],
#  ['<BOS>', '他', '来', '了', '<EOS>'],
#  ['<BOS>', '他', '跑', '<EOS>'],
#  ['<BOS>', '帮', '我', '一', '下', '<EOS>'],
#  ['<BOS>', '坚', '持', '<EOS>'],
#  ['<BOS>', '抱', '抱', '汤', '姆', '<EOS>'],
#  ['<BOS>', '我', '同', '意', '<EOS>'],
#  ['<BOS>', '我', '生', '病', '了', '<EOS>'],
#  ['<BOS>', '我', '老', '了', '<EOS>'],
#  ['<BOS>', '没', '关', '系', '<EOS>'],
#  ['<BOS>', '是', '我', '<EOS>'],
#  ['<BOS>', '来', '加', '入', '我', '们', '吧', '<EOS>'],
#  ['<BOS>', '留', '着', '吧', '<EOS>'],
#  ['<BOS>', '吻', '我', '<EOS>'],
#  ['<BOS>', '完', '美', '<EOS>'],
#  ['<BOS>', '再', '见', '<EOS>'],
#  ['<BOS>', '閉', '嘴', '<EOS>'],
#  ['<BOS>', '不', '管', '它', '<EOS>'],
#  ['<BOS>', '拿', '走', '吧', '<EOS>'],
#  ['<BOS>', '醒', '醒', '<EOS>'],
#  ['<BOS>', '去', '清', '洗', '一', '下', '<EOS>'],
#  ['<BOS>', '我', '们', '知', '道', '<EOS>'],
#  ['<BOS>', '欢', '迎', '<EOS>'],
#  ['<BOS>', '谁', '赢', '了', '<EOS>'],
#  ['<BOS>', '为', '什', '么', '不', '<EOS>'],
#  ['<BOS>', '你', '跑', '<EOS>'],
#  ['<BOS>', '往', '后', '退', '点', '<EOS>'],
#  ['<BOS>', '静', '静', '的', '别', '动', '<EOS>'],
#  ['<BOS>', '把', '他', '铐', '上', '<EOS>'],
#  ['<BOS>', '往', '前', '开', '<EOS>'],
#  ['<BOS>', '走', '開', '<EOS>'],
#  ['<BOS>', '滾', '<EOS>'],
#  ['<BOS>', '趴', '下', '<EOS>'],
#  ['<BOS>', '滾', '<EOS>'],
#  ['<BOS>', '醒', '醒', '吧', '<EOS>'],
#  ['<BOS>', '抓', '住', '汤', '姆', '<EOS>'],
#  ['<BOS>', '抓', '住', '他', '<EOS>'],
#  ['<BOS>', '玩', '得', '開', '心', '<EOS>'],
#  ['<BOS>', '他', '来', '试', '试', '<EOS>'],
#  ['<BOS>', '你', '就', '随', '了', '我', '的', '意', '吧', '<EOS>'],
#  ['<BOS>', '趕', '快', '<EOS>'],
#  ['<BOS>', '快', '点', '<EOS>'],
#  ['<BOS>', '我', '忘', '了', '<EOS>'],
#  ['<BOS>', '我', '放', '弃', '<EOS>'],
#  ['<BOS>', '我', '來', '付', '錢', '<EOS>'],
#  ['<BOS>', '我', '很', '忙', '<EOS>'],
#  ['<BOS>', '我', '冷', '<EOS>'],
#  ['<BOS>', '我', '很', '好', '<EOS>'],
#  ['<BOS>', '我', '吃', '飽', '了', '<EOS>'],
#  ['<BOS>', '我', '生', '病', '了', '<EOS>'],
#  ['<BOS>', '我', '病', '了', '<EOS>'],
#  ['<BOS>', '让', '我', '一', '个', '人', '呆', '会', '儿', '<EOS>'],
#  ['<BOS>', '走', '吧', '<EOS>'],
#  ['<BOS>', '我', '們', '開', '始', '吧', '<EOS>'],
#  ['<BOS>', '我', '們', '走', '吧', '<EOS>'],
#  ['<BOS>', '当', '心', '<EOS>'],
#  ['<BOS>', '她', '跑', '<EOS>'],
#  ['<BOS>', '起', '立', '<EOS>'],
#  ['<BOS>', '他', '们', '赢', '了', '<EOS>'],
#  ['<BOS>', '汤', '姆', '去', '世', '了', '<EOS>'],
#  ['<BOS>', '汤', '姆', '不', '干', '了', '<EOS>'],
#  ['<BOS>', '汤', '姆', '游', '泳', '了', '<EOS>'],
#  ['<BOS>', '相', '信', '我', '<EOS>'],
#  ['<BOS>', '努', '力', '<EOS>'],
#  ['<BOS>', '试', '试', '吧', '<EOS>'],
#  ['<BOS>', '谁', '死', '了', '<EOS>'],
#  ['<BOS>', '鳥', '類', '飛', '行', '<EOS>'],
#  ['<BOS>', '打', '电', '话', '回', '家', '<EOS>'],
#  ['<BOS>', '抓', '住', '他', '<EOS>'],
#  ['<BOS>', '回', '家', '吧', '<EOS>'],
#  ['<BOS>', '現', '在', '就', '做', '<EOS>'],
#  ['<BOS>', '狗', '会', '叫', '<EOS>'],
#  ['<BOS>', '别', '哭', '<EOS>'],
#  ['<BOS>', '对', '不', '起', '<EOS>'],
#  ['<BOS>', '来', '感', '受', '一', '下', '这', '个', '<EOS>'],
#  ['<BOS>', '请', '跟', '我', '来', '<EOS>'],
#  ['<BOS>', '请', '跟', '着', '我', '们', '<EOS>'],
#  ['<BOS>', '祝', '你', '好', '运', '<EOS>'],
#  ['<BOS>', '抓', '住', '那', '个', '<EOS>'],
#  ['<BOS>', '抓', '住', '这', '个', '<EOS>'],
#  ['<BOS>', '手', '举', '起', '来', '<EOS>'],
#  ['<BOS>', '他', '是', '一', '个', '<EOS>'],
#  ['<BOS>', '他', '很', '懒', '<EOS>'],
#  ['<BOS>', '停', '火', '<EOS>'],
#  ['<BOS>', '我', '住', '这', '个', '<EOS>'],
#  ['<BOS>', '太', '可', '怕', '了', '<EOS>'],
#  ['<BOS>', '我', '冷', '<EOS>'],
#  ['<BOS>', '我', '沒', '事', '<EOS>'],
#  ['<BOS>', '我', '生', '病', '了', '<EOS>'],
#  ['<BOS>', '我', '了', '解', '你', '<EOS>'],
#  ['<BOS>', '我', '希', '望', '如', '此', '<EOS>'],
#  ['<BOS>', '我', '笑', '了', '<EOS>'],
#  ['<BOS>', '我', '向', '你', '保', '证', '<EOS>'],
#  ['<BOS>', '我', '看', '見', '湯', '姆', '了', '<EOS>'],
#  ['<BOS>', '我', '是', '个', '男', '人', '<EOS>'],
#  ['<BOS>', '我', '是', '對', '的', '<EOS>'],
#  ['<BOS>', '对', '不', '起', '<EOS>'],
#  ['<BOS>', '我', '很', '抱', '歉', '<EOS>'],
#  ['<BOS>', '我', '還', '年', '輕', '<EOS>'],
#  ['<BOS>', '遠', '嗎', '<EOS>'],
#  ['<BOS>', '下', '雪', '了', '<EOS>'],
#  ['<BOS>', '点', '半', '了', '<EOS>'],
#  ['<BOS>', '天', '很', '冷', '<EOS>'],
#  ['<BOS>', '它', '是', '免', '費', '的', '<EOS>'],
#  ['<BOS>', '很', '晚', '了', '<EOS>'],
#  ['<BOS>', '這', '是', '真', '的', '<EOS>'],
#  ['<BOS>', '让', '我', '进', '去', '<EOS>'],
#  ['<BOS>', '躺', '着', '不', '动', '<EOS>'],
#  ['<BOS>', '回', '头', '看', '<EOS>'],
#  ['<BOS>', '腾', '一', '下', '地', '方', '<EOS>'],
#  ['<BOS>', '當', '然', '<EOS>'],
#  ['<BOS>', '當', '然', '<EOS>'],
#  ['<BOS>', '当', '然', '了', '<EOS>'],
#  ['<BOS>', '噢', '拜', '托', '了', '<EOS>'],
#  ['<BOS>', '开', '火', '<EOS>'],
#  ['<BOS>', '念', '这', '个', '<EOS>'],
#  ['<BOS>', '参', '见', '上', '文', '<EOS>'],
#  ['<BOS>', '她', '哭', '了', '<EOS>'],
#  ['<BOS>', '她', '试', '过', '了', '<EOS>'],
#  ['<BOS>', '她', '在', '行', '走', '<EOS>'],
#  ['<BOS>', '耐', '心', '等', '着', '<EOS>'],
#  ['<BOS>', '慢', '一', '點', '<EOS>'],
#  ['<BOS>', '保', '持', '冷', '靜', '<EOS>'],
#  ['<BOS>', '趴', '着', '<EOS>'],
#  ['<BOS>', '住', '手', '<EOS>'],
#  ['<BOS>', '照', '顾', '好', '自', '己', '<EOS>'],
#  ['<BOS>', '照', '顾', '好', '自', '己', '<EOS>'],
#  ['<BOS>', '游', '泳', '<EOS>'],
#  ['<BOS>', '湯', '姆', '累', '了', '<EOS>'],
#  ['<BOS>', '汤', '姆', '挥', '手', '了', '<EOS>'],
#  ['<BOS>', '向', '左', '转', '<EOS>'],
#  ['<BOS>', '在', '这', '等', '着', '<EOS>'],
#  ['<BOS>', '做', '得', '好', '<EOS>'],
#  ['<BOS>', '爱', '谁', '谁', '<EOS>'],
#  ['<BOS>', '很', '棒', '<EOS>'],
#  ['<BOS>', '蠢', '货', '<EOS>'],
#  ['<BOS>', '请', '上', '船', '<EOS>'],
#  ['<BOS>', '我', '錯', '了', '嗎', '<EOS>'],
#  ['<BOS>', '鳥', '兒', '歌', '唱', '<EOS>'],
#  ['<BOS>', '我', '可', '以', '幫', '忙', '嗎', '<EOS>'],
#  ['<BOS>', '快', '点', '<EOS>'],
#  ['<BOS>', '必', '须', '的', '<EOS>'],
#  ['<BOS>', '别', '动', '<EOS>'],
#  ['<BOS>', '不', '要', '动', '<EOS>'],
#  ['<BOS>', '把', '它', '填', '滿', '<EOS>'],
#  ['<BOS>', '跟', '著', '他', '走', '<EOS>'],
#  ['<BOS>', '上', '帝', '存', '在', '<EOS>'],
#  ['<BOS>', '晚', '安', '<EOS>'],
#  ['<BOS>', '他', '让', '步', '了', '<EOS>'],
#  ['<BOS>', '他', '很', '凶', '<EOS>'],
#  ['<BOS>', '他', '很', '穷', '<EOS>'],
#  ['<BOS>', '他', '高', '<EOS>'],
#  ['<BOS>', '你', '好', '汤', '姆', '<EOS>'],
#  ['<BOS>', '嘿', '放', '松', '点', '<EOS>'],
#  ['<BOS>', '多', '可', '爱', '啊', '<EOS>'],
#  ['<BOS>', '赶', '快', '回', '家', '<EOS>'],
#  ['<BOS>', '我', '是', '个', '男', '人', '<EOS>'],
#  ['<BOS>', '我', '个', '头', '矮', '<EOS>'],
#  ['<BOS>', '我', '会', '做', '饭', '<EOS>'],
#  ['<BOS>', '我', '會', '游', '泳', '<EOS>'],
#  ['<BOS>', '我', '在', '這', '裡', '吃', '<EOS>'],
#  ['<BOS>', '我', '嫉', '妒', '她', '<EOS>'],
#  ['<BOS>', '我', '羡', '慕', '他', '<EOS>'],
#  ['<BOS>', '我', '恨', '你', '<EOS>'],
#  ['<BOS>', '我', '认', '识', '汤', '姆', '<EOS>'],
#  ['<BOS>', '我', '認', '識', '他', '<EOS>'],
#  ['<BOS>', '我', '喜', '欢', '茶', '<EOS>'],
#  ['<BOS>', '我', '喜', '歡', '你', '<EOS>'],
#  ['<BOS>', '我', '喜', '欢', '你', '<EOS>'],
#  ['<BOS>', '我', '愛', '她', '<EOS>'],
#  ['<BOS>', '我', '爱', '您', '<EOS>'],
#  ['<BOS>', '我', '想', '念', '你', '<EOS>'],
#  ['<BOS>', '我', '需', '要', '你', '<EOS>'],
#  ['<BOS>', '我', '想', '是', '這', '樣', '的', '<EOS>'],
#  ['<BOS>', '我', '使', '用', '这', '个', '<EOS>'],
#  ['<BOS>', '我', '會', '做', '的', '<EOS>'],
#  ['<BOS>', '我', '是', '個', '英', '雄', '<EOS>'],
#  ['<BOS>', '我', '是', '谦', '虚', '的', '<EOS>'],
#  ['<BOS>', '我', '单', '身', '<EOS>'],
#  ['<BOS>', '我', '困', '了', '<EOS>'],
#  ['<BOS>', '我', '好', '胖', '哦', '<EOS>'],
#  ['<BOS>', '别', '理', '汤', '姆', '<EOS>'],
#  ['<BOS>', '那', '是', '愛', '嗎', '<EOS>'],
#  ['<BOS>', '真', '是', '太', '好', '了', '<EOS>'],
#  ['<BOS>', '是', '晚', '上', '了', '<EOS>'],
#  ['<BOS>', '放', '松', '点', '吧', '<EOS>'],
#  ['<BOS>', '保', '持', '安', '静', '<EOS>'],
#  ['<BOS>', '让', '他', '进', '来', '<EOS>'],
#  ['<BOS>', '让', '我', '去', '死', '<EOS>'],
#  ['<BOS>', '让', '我', '想', '一', '想', '<EOS>'],
#  ['<BOS>', '我', '们', '走', '走', '吧', '<EOS>'],
#  ['<BOS>', '看', '那', '里', '<EOS>'],
#  ['<BOS>', '禁', '止', '评', '论', '<EOS>'],
#  ['<BOS>', '没', '问', '题', '<EOS>'],
#  ['<BOS>', '没', '关', '系', '<EOS>'],
#  ['<BOS>', '没', '问', '题', '<EOS>'],
#  ['<BOS>', '噢', '真', '的', '嗎', '<EOS>'],
#  ['<BOS>', '再', '一', '次', '<EOS>'],
#  ['<BOS>', '她', '笑', '了', '<EOS>'],
#  ['<BOS>', '往', '后', '站', '<EOS>'],
#  ['<BOS>', '保', '持', '警', '惕', '<EOS>'],
#  ['<BOS>', '留', '在', '这', '里', '别', '动', '<EOS>'],
#  ['<BOS>', '让', '开', '<EOS>'],
#  ['<BOS>', '好', '好', '学', '习', '<EOS>'],
#  ['<BOS>', '真', '疼', '<EOS>'],
#  ['<BOS>', '時', '光', '飛', '逝', '<EOS>'],
#  ['<BOS>', '汤', '姆', '害', '羞', '<EOS>'],
#  ['<BOS>', '汤', '姆', '笑', '了', '<EOS>'],
#  ['<BOS>', '汤', '姆', '打', '哈', '欠', '了', '<EOS>'],
#  ['<BOS>', '向', '右', '转', '<EOS>'],
#  ['<BOS>', '我', '们', '笑', '了', '<EOS>'],
#  ['<BOS>', '我', '们', '失', '去', '了', '它', '<EOS>'],
#  ['<BOS>', '這', '是', '什', '麼', '啊', '<EOS>'],
#  ['<BOS>', '有', '什', '么', '新', '鲜', '事', '吗', '<EOS>'],
#  ['<BOS>', '我', '在', '哪', '裡', '<EOS>'],
#  ['<BOS>', '這', '是', '什', '麼', '地', '方', '<EOS>'],
#  ['<BOS>', '我', '們', '是', '誰', '<EOS>'],
#  ['<BOS>', '木', '材', '燃', '燒', '<EOS>'],
#  ['<BOS>', '我', '们', '完', '成', '了', '吗', '<EOS>'],
#  ['<BOS>', '你', '是', '汤', '姆', '吗', '<EOS>'],
#  ['<BOS>', '您', '生', '气', '了', '吗', '<EOS>'],
#  ['<BOS>', '你', '生', '气', '了', '吗', '<EOS>'],
#  ['<BOS>', '你', '傷', '心', '嗎', '<EOS>'],
#  ['<BOS>', '友', '好', '点', '<EOS>'],
#  ['<BOS>', '停', '手', '<EOS>'],
#  ['<BOS>', '你', '能', '看', '吗', '<EOS>'],
#  ['<BOS>', '算', '我', '一', '个', '<EOS>'],
#  ['<BOS>', '按', '我', '說', '的', '做', '<EOS>'],
#  ['<BOS>', '別', '走', '<EOS>'],
#  ['<BOS>', '不', '要', '恐', '慌', '<EOS>'],
#  ['<BOS>', '不', '许', '大', '叫', '<EOS>'],
#  ['<BOS>', '別', '擔', '心', '<EOS>'],
#  ['<BOS>', '别', '擔', '心', '<EOS>'],
#  ['<BOS>', '认', '真', '点', '<EOS>'],
#  ['<BOS>', '他', '獨', '自', '一', '人', '<EOS>'],
#  ['<BOS>', '他', '醉', '了', '<EOS>'],
#  ['<BOS>', '他', '很', '強', '壯', '<EOS>'],
#  ['<BOS>', '我', '們', '到', '了', '<EOS>'],
#  ['<BOS>', '这', '里', '快', '抓', '住', '<EOS>'],
#  ['<BOS>', '你', '們', '好', '嗎', '<EOS>'],
#  ['<BOS>', '你', '好', '嗎', '<EOS>'],
#  ['<BOS>', '多', '怪', '啊', '<EOS>'],
#  ['<BOS>', '真', '奇', '怪', '<EOS>'],
#  ['<BOS>', '我', '來', '了', '<EOS>'],
#  ['<BOS>', '我', '買', '磁', '帶', '<EOS>'],
#  ['<BOS>', '我', '不', '能', '说', '<EOS>'],
#  ['<BOS>', '我', '不', '說', '謊', '<EOS>'],
#  ['<BOS>', '我', '吃', '面', '包', '<EOS>'],
#  ['<BOS>', '我', '觉', '得', '冷', '<EOS>'],
#  ['<BOS>', '我', '感', '觉', '很', '好', '<EOS>'],
#  ['<BOS>', '我', '感', '到', '虚', '弱', '<EOS>'],
#  ['<BOS>', '我', '有', '时', '间', '<EOS>'],
#  ['<BOS>', '我', '聽', '你', '的', '<EOS>'],
#  ['<BOS>', '我', '喜', '欢', '鱼', '<EOS>'],
#  ['<BOS>', '我', '喜', '歡', '爵', '士', '樂', '<EOS>'],
#  ['<BOS>', '我', '住', '在', '這', '<EOS>'],
#  ['<BOS>', '我', '需', '要', '胶', '水', '<EOS>'],
#  ['<BOS>', '我', '睡', '过', '头', '了', '<EOS>'],
#  ['<BOS>', '我', '是', '那', '樣', '說', '的', '<EOS>'],
#  ['<BOS>', '我', '聞', '到', '瓦', '斯', '味', '<EOS>'],
#  ['<BOS>', '我', '信', '任', '他', '<EOS>'],
#  ['<BOS>', '我', '信', '任', '你', '<EOS>'],
#  ['<BOS>', '我', '想', '要', '更', '多', '<EOS>'],
#  ['<BOS>', '我', '搞', '错', '了', '<EOS>'],
#  ['<BOS>', '我', '会', '听', '从', '指', '示', '<EOS>'],
#  ['<BOS>', '我', '會', '等', '<EOS>'],
#  ['<BOS>', '我', '在', '這', '裡', '工', '作', '<EOS>'],
#  ['<BOS>', '我', '會', '參', '加', '<EOS>'],
#  ['<BOS>', '我', '會', '進', '去', '<EOS>'],
#  ['<BOS>', '我', '也', '是', '岁', '<EOS>'],
#  ['<BOS>', '我', '是', '個', '不', '成', '器', '的', '人', '<EOS>'],
#  ['<BOS>', '我', '在', '家', '<EOS>'],
#  ['<BOS>', '我', '很', '好', '奇', '<EOS>'],
#  ['<BOS>', '我', '结', '婚', '了', '<EOS>'],
#  ['<BOS>', '我', '已', '婚', '<EOS>'],
#  ['<BOS>', '我', '在', '读', '书', '<EOS>'],
#  ['<BOS>', '我', '是', '認', '真', '的', '<EOS>'],
#  ['<BOS>', '我', '渴', '了', '<EOS>'],
#  ['<BOS>', '汤', '姆', '还', '好', '吧', '<EOS>'],
#  ['<BOS>', '这', '是', '你', '的', '吗', '<EOS>'],
#  ['<BOS>', '这', '不', '可', '能', '<EOS>'],
#  ['<BOS>', '不', '可', '能', '<EOS>'],
#  ['<BOS>', '這', '是', '我', '份', '內', '的', '事', '<EOS>'],
#  ['<BOS>', '只', '要', '說', '不', '<EOS>'],
#  ['<BOS>', '继', '续', '努', '力', '<EOS>'],
#  ['<BOS>', '讓', '我', '知', '道', '<EOS>'],
#  ['<BOS>', '讓', '我', '們', '開', '始', '吧', '<EOS>'],
#  ['<BOS>', '走', '吧', '<EOS>'],
#  ['<BOS>', '讓', '我', '們', '開', '始', '吧', '<EOS>'],
#  ['<BOS>', '人', '生', '是', '有', '趣', '的', '<EOS>'],
#  ['<BOS>', '四', '处', '看', '看', '<EOS>'],
#  ['<BOS>', '午', '餐', '送', '到', '了', '<EOS>'],
#  ['<BOS>', '非', '常', '感', '谢', '<EOS>'],
#  ['<BOS>', '金', '钱', '万', '能', '<EOS>'],
#  ['<BOS>', '好', '时', '机', '<EOS>'],
#  ['<BOS>', '没', '有', '人', '来', '了', '<EOS>'],
#  ['<BOS>', '好', '我', '同', '意', '<EOS>'],
#  ['<BOS>', '请', '来', '吧', '<EOS>'],
#  ['<BOS>', '请', '唱', '歌', '<EOS>'],
#  ['<BOS>', '放', '开', '他', '<EOS>'],
#  ['<BOS>', '她', '打', '了', '他', '<EOS>'],
#  ['<BOS>', '一', '边', '站', '着', '<EOS>'],
#  ['<BOS>', '进', '来', '<EOS>'],
#  ['<BOS>', '這', '就', '是', '生', '活', '<EOS>'],
#  ['<BOS>', '人', '生', '就', '是', '如', '此', '<EOS>'],
#  ['<BOS>', '這', '是', '真', '的', '<EOS>'],
#  ['<BOS>', '他', '们', '拥', '抱', '<EOS>'],
#  ['<BOS>', '他', '们', '亲', '吻', '了', '<EOS>'],
#  ['<BOS>', '這', '是', '冰', '塊', '<EOS>'],
#  ['<BOS>', '汤', '姆', '脸', '红', '了', '<EOS>'],
#  ['<BOS>', '湯', '姆', '皺', '著', '眉', '頭', '<EOS>'],
#  ['<BOS>', '汤', '姆', '变', '胖', '了', '<EOS>'],
#  ['<BOS>', '湯', '姆', '看', '見', '你', '了', '<EOS>'],
#  ['<BOS>', '湯', '姆', '會', '等', '<EOS>'],
#  ['<BOS>', '湯', '姆', '錯', '了', '<EOS>'],
#  ['<BOS>', '转', '过', '来', '<EOS>'],
#  ['<BOS>', '我', '错', '了', '吗', '<EOS>'],
#  ['<BOS>', '我', '們', '是', '男', '孩', '<EOS>'],
#  ['<BOS>', '我', '們', '遲', '到', '了', '<EOS>'],
#  ['<BOS>', '我', '們', '都', '贏', '了', '<EOS>'],
#  ['<BOS>', '我', '们', '可', '以', '休', '息', '<EOS>'],
#  ['<BOS>', '我', '們', '認', '識', '他', '<EOS>'],
#  ['<BOS>', '我', '们', '爱', '汤', '姆', '<EOS>'],
#  ['<BOS>', '我', '们', '想', '要', '汤', '姆', '<EOS>'],
#  ['<BOS>', '太', '可', '惜', '了', '<EOS>'],
#  ['<BOS>', '多', '遗', '憾', '啊', '<EOS>'],
#  ['<BOS>', '有', '什', '么', '新', '鲜', '事', '吗', '<EOS>'],
#  ['<BOS>', '那', '是', '什', '么', '<EOS>'],
#  ['<BOS>', '這', '是', '什', '麼', '啊', '<EOS>'],
#  ['<BOS>', '那', '是', '什', '么', '<EOS>'],
#  ['<BOS>', '你', '是', '誰', '<EOS>'],
#  ['<BOS>', '誰', '畫', '的', '<EOS>'],
#  ['<BOS>', '那', '是', '谁', '<EOS>'],
#  ['<BOS>', '这', '是', '谁', '的', '<EOS>'],
#  ['<BOS>', '木', '头', '会', '漂', '浮', '<EOS>'],
#  ['<BOS>', '干', '活', '慢', '点', '<EOS>'],
#  ['<BOS>', '你', '有', '病', '<EOS>'],
#  ['<BOS>', '有', '什', '么', '新', '鲜', '事', '吗', '<EOS>'],
#  ['<BOS>', '你', '忙', '嗎', '<EOS>'],
#  ['<BOS>', '您', '迷', '路', '了', '吗', '<EOS>'],
#  ['<BOS>', '你', '迷', '路', '了', '吗', '<EOS>'],
#  ['<BOS>', '你', '确', '定', '吗', '<EOS>'],
#  ['<BOS>', '现', '实', '点', '<EOS>'],
#  ['<BOS>', '带', '他', '进', '来', '<EOS>'],
#  ['<BOS>', '现', '在', '给', '汤', '姆', '打', '电', '话', '<EOS>'],
#  ['<BOS>', '我', '们', '能', '做', '到', '吗', '<EOS>'],
#  ['<BOS>', '你', '能', '來', '嗎', '<EOS>'],
#  ['<BOS>', '你', '能', '閱', '讀', '嗎', '<EOS>'],
#  ['<BOS>', '你', '會', '游', '泳', '嗎', '<EOS>'],
#  ['<BOS>', '你', '打', '過', '電', '話', '了', '嗎', '<EOS>'],
#  ['<BOS>', '你', '吸', '烟', '吗', '<EOS>'],
#  ['<BOS>', '盡', '力', '而', '為', '<EOS>'],
#  ['<BOS>', '不', '要', '害', '羞', '<EOS>'],
#  ['<BOS>', '不', '用', '麻', '烦', '了', '<EOS>'],
#  ['<BOS>', '别', '来', '烦', '我', '<EOS>'],
#  ['<BOS>', '安', '全', '地', '駕', '駛', '<EOS>'],
#  ['<BOS>', '开', '车', '慢', '点', '<EOS>'],
#  ['<BOS>', '鬼', '魂', '是', '存', '在', '的', '<EOS>'],
#  ['<BOS>', '还', '回', '去', '<EOS>'],
#  ['<BOS>', '晚', '上', '好', '<EOS>'],
#  ['<BOS>', '晚', '上', '好', '<EOS>'],
#  ['<BOS>', '早', '上', '好', '<EOS>'],
#  ['<BOS>', '他', '生', '气', '了', '<EOS>'],
#  ['<BOS>', '他', '喜', '歡', '茶', '<EOS>'],
#  ['<BOS>', '他', '愛', '她', '<EOS>'],
#  ['<BOS>', '他', '很', '勇', '敢', '<EOS>'],
#  ['<BOS>', '真', '烦', '人', '<EOS>'],
#  ['<BOS>', '你', '敢', '<EOS>'],
#  ['<BOS>', '真', '糟', '糕', '<EOS>'],
#  ['<BOS>', '我', '欣', '赏', '你', '<EOS>'],
#  ['<BOS>', '我', '几', '乎', '赢', '了', '<EOS>'],
#  ['<BOS>', '我', '在', '家', '<EOS>'],
#  ['<BOS>', '我', '很', '好', '奇', '<EOS>'],
#  ['<BOS>', '我', '结', '婚', '了', '<EOS>'],
#  ['<BOS>', '我', '在', '祈', '禱', '<EOS>'],
#  ['<BOS>', '我', '渴', '了', '<EOS>'],
#  ['<BOS>', '我', '吃', '了', '魚', '子', '醬', '<EOS>'],
#  ['<BOS>', '我', '給', '湯', '姆', '打', '了', '電', '話', '<EOS>'],
#  ['<BOS>', '我', '无', '所', '谓', '<EOS>'],
#  ['<BOS>', '我', '有', '一', '辆', '车', '<EOS>'],
#  ['<BOS>', '我', '有', '一', '条', '狗', '<EOS>'],
#  ['<BOS>', '我', '有', '一', '張', '地', '圖', '<EOS>'],
#  ['<BOS>', '我', '喜', '欢', '这', '些', '<EOS>'],
#  ['<BOS>', '我', '爱', '音', '乐', '<EOS>'],
#  ['<BOS>', '我', '想', '你', '<EOS>'],
#  ['<BOS>', '我', '看', '到', '一', '本', '書', '<EOS>'],
#  ['<BOS>', '我', '明', '白', '了', '<EOS>'],
#  ['<BOS>', '我', '想', '要', '一', '隻', '狗', '<EOS>'],
#  ['<BOS>', '我', '要', '告', '你', '<EOS>'],
#  ['<BOS>', '我', '洗', '耳', '恭', '聽', '<EOS>'],
#  ['<BOS>', '我', '现', '在', '有', '空', '了', '<EOS>'],
#  ['<BOS>', '我', '是', '清', '白', '的', '<EOS>'],
#  ['<BOS>', '我', '不', '确', '定', '<EOS>'],
#  ['<BOS>', '我', '怀', '孕', '了', '<EOS>'],
#  ['<BOS>', '我', '好', '高', '興', '<EOS>'],
#  ['<BOS>', '我', '好', '累', '<EOS>'],
#  ['<BOS>', '我', '饿', '死', '了', '<EOS>'],
#  ['<BOS>', '我', '餓', '死', '了', '<EOS>'],
#  ['<BOS>', '我', '是', '最', '好', '的', '<EOS>'],
#  ['<BOS>', '我', '激', '動', '不', '已', '<EOS>'],
#  ['<BOS>', '我', '決', '定', '了', '<EOS>'],
#  ['<BOS>', '那', '是', '愛', '嗎', '<EOS>'],
#  ['<BOS>', '真', '的', '<EOS>'],
#  ['<BOS>', '太', '神', '奇', '了', '<EOS>'],
#  ['<BOS>', '它', '是', '明', '顯', '的', '<EOS>'],
#  ['<BOS>', '下', '雨', '了', '<EOS>'],
#  ['<BOS>', '在', '下', '雨', '<EOS>'],
#  ['<BOS>', '正', '在', '下', '雪', '<EOS>'],
#  ['<BOS>', '太', '难', '了', '<EOS>'],
#  ['<BOS>', '它', '太', '大', '了', '<EOS>'],
#  ['<BOS>', '繼', '續', '看', '<EOS>'],
#  ['<BOS>', '继', '续', '看', '<EOS>'],
#  ['<BOS>', '繼', '續', '工', '作', '<EOS>'],
#  ['<BOS>', '讓', '我', '想', '一', '想', '<EOS>'],
#  ['<BOS>', '我', '们', '现', '在', '去', '吧', '<EOS>'],
#  ['<BOS>', '人', '生', '會', '繼', '續', '<EOS>'],
#  ['<BOS>', '瑪', '麗', '進', '來', '了', '<EOS>'],
#  ['<BOS>', '瑪', '麗', '很', '高', '<EOS>'],
#  ['<BOS>', '我', '现', '在', '能', '去', '了', '吗', '<EOS>'],
#  ['<BOS>', '轻', '轻', '地', '移', '动', '<EOS>'],
#  ['<BOS>', '我', '的', '眼', '睛', '痛', '<EOS>'],
#  ['<BOS>', '沒', '有', '人', '知', '道', '<EOS>'],
#  ['<BOS>', '没', '人', '问', '过', '<EOS>'],
#  ['<BOS>', '打', '開', '箱', '子', '<EOS>'],
#  ['<BOS>', '请', '抓', '紧', '时', '间', '<EOS>'],
#  ['<BOS>', '請', '你', '離', '開', '<EOS>'],
#  ['<BOS>', '一', '会', '儿', '见', '<EOS>'],
#  ['<BOS>', '到', '時', '候', '見', '<EOS>'],
#  ['<BOS>', '你', '真', '丢', '脸', '<EOS>'],
#  ['<BOS>', '你', '真', '丢', '脸', '<EOS>'],
#  ['<BOS>', '她', '很', '安', '静', '<EOS>'],
#  ['<BOS>', '她', '心', '情', '不', '好', '<EOS>'],
#  ['<BOS>', '她', '可', '以', '來', '<EOS>'],
#  ['<BOS>', '她', '也', '許', '來', '<EOS>'],
#  ['<BOS>', '有', '人', '来', '了', '<EOS>'],
#  ['<BOS>', '别', '再', '傻', '看', '着', '<EOS>'],
#  ['<BOS>', '别', '再', '念', '了', '<EOS>'],
#  ['<BOS>', '别', '再', '盯', '着', '了', '<EOS>'],
#  ['<BOS>', '不', '要', '说', '话', '了', '<EOS>'],
#  ['<BOS>', '别', '再', '埋', '怨', '了', '<EOS>'],
#  ['<BOS>', '别', '再', '喊', '叫', '了', '<EOS>'],
#  ['<BOS>', '祝', '你', '好', '梦', '<EOS>'],
#  ['<BOS>', '放', '輕', '鬆', '<EOS>'],
#  ['<BOS>', '別', '緊', '張', '<EOS>'],
#  ['<BOS>', '带', '我', '回', '家', '<EOS>'],
#  ['<BOS>', '告', '訴', '我', '們', '多', '一', '點', '<EOS>'],
#  ['<BOS>', '那', '是', '我', '的', '<EOS>'],
#  ['<BOS>', '那', '是', '瘋', '狂', '的', '<EOS>'],
#  ['<BOS>', '那', '真', '是', '太', '好', '了', '<EOS>'],
#  ['<BOS>', '对', '<EOS>'],
#  ['<BOS>', '他', '們', '拒', '絕', '了', '<EOS>'],
#  ['<BOS>', '这', '是', '我', '的', '<EOS>'],
#  ['<BOS>', '這', '是', '真', '的', '<EOS>'],
#  ['<BOS>', '汤', '姆', '跟', '着', '<EOS>'],
#  ['<BOS>', '湯', '姆', '高', '興', '<EOS>'],
#  ['<BOS>', '認', '識', '我', '<EOS>'],
#  ['<BOS>', '汤', '姆', '坐', '下', '了', '<EOS>'],
#  ['<BOS>', '汤', '姆', '告', '诉', '了', '他', '<EOS>'],
#  ['<BOS>', '汤', '姆', '饱', '了', '<EOS>'],
#  ['<BOS>', '汤', '姆', '快', '起', '来', '<EOS>'],
#  ['<BOS>', '再', '試', '一', '次', '<EOS>'],
#  ['<BOS>', '難', '以', '置', '信', '<EOS>'],
#  ['<BOS>', '难', '以', '置', '信', '<EOS>'],
#  ['<BOS>', '投', '票', '給', '湯', '姆', '<EOS>'],
#  ['<BOS>', '我', '們', '很', '快', '樂', '<EOS>'],
#  ['<BOS>', '我', '們', '能', '開', '始', '<EOS>'],
#  ['<BOS>', '我', '們', '需', '要', '更', '多', '<EOS>'],
#  ['<BOS>', '我', '们', '成', '功', '了', '<EOS>'],
#  ['<BOS>', '我', '們', '投', '降', '<EOS>'],
#  ['<BOS>', '我', '们', '在', '藏', '着', '<EOS>'],
#  ['<BOS>', '欢', '迎', '回', '来', '<EOS>'],
#  ['<BOS>', '愛', '是', '什', '麼', '<EOS>'],
#  ['<BOS>', '那', '是', '什', '么', '<EOS>'],
#  ['<BOS>', '這', '是', '什', '麼', '啊', '<EOS>'],
#  ['<BOS>', '这', '是', '谁', '建', '的', '<EOS>'],
#  ['<BOS>', '谁', '来', '了', '这', '里', '<EOS>'],
#  ['<BOS>', '多', '少', '年', '过', '去', '了', '<EOS>'],
#  ['<BOS>', '还', '有', '别', '的', '吗', '<EOS>'],
#  ['<BOS>', '您', '生', '气', '了', '吗', '<EOS>'],
#  ['<BOS>', '你', '生', '气', '了', '吗', '<EOS>'],
#  ['<BOS>', '你', '快', '樂', '嗎', '<EOS>'],
#  ['<BOS>', '您', '准', '备', '好', '了', '吗', '<EOS>'],
#  ['<BOS>', '你', '们', '准', '备', '好', '了', '吗', '<EOS>'],
#  ['<BOS>', '你', '准', '备', '好', '了', '吗', '<EOS>'],
#  ['<BOS>', '你', '累', '了', '嗎', '<EOS>'],
#  ['<BOS>', '帶', '鑰', '匙', '來', '<EOS>'],
#  ['<BOS>', '叫', '保', '安', '来', '<EOS>'],
#  ['<BOS>', '你', '会', '溜', '冰', '吗', '<EOS>'],
#  ['<BOS>', '請', '結', '帳', '<EOS>'],
#  ['<BOS>', '不', '要', '放', '棄', '<EOS>'],
#  ['<BOS>', '画', '一', '个', '圈', '<EOS>'],
#  ['<BOS>', '鮮', '花', '盛', '開', '<EOS>'],
#  ['<BOS>', '他', '不', '會', '游', '泳', '<EOS>'],
#  ['<BOS>', '这', '是', '一', '个', '小', '偷', '<EOS>'],
#  ['<BOS>', '他', '在', '家', '裡', '<EOS>'],
#  ['<BOS>', '他', '是', '我', '的', '菜', '<EOS>'],
#  ['<BOS>', '他', '不', '是', '傻', '子', '<EOS>'],
#  ['<BOS>', '他', '没', '疯', '<EOS>'],
#  ['<BOS>', '他', '不', '在', '家', '<EOS>'],
#  ['<BOS>', '他', '欺', '騙', '了', '我', '們', '<EOS>'],
#  ['<BOS>', '他', '賣', '車', '子', '<EOS>'],
#  ['<BOS>', '他', '槍', '擊', '了', '我', '<EOS>'],
#  ['<BOS>', '他', '努', '力', '地', '嘗', '試', '<EOS>'],
#  ['<BOS>', '他', '想', '要', '更', '多', '<EOS>'],
#  ['<BOS>', '他', '不', '在', '家', '<EOS>'],
#  ['<BOS>', '你', '怎', '麼', '樣', '<EOS>'],
#  ['<BOS>', '那', '你', '呢', '<EOS>'],
#  ['<BOS>', '你', '們', '呢', '<EOS>'],
#  ['<BOS>', '您', '呢', '<EOS>'],
#  ['<BOS>', '多', '美', '啊', '<EOS>'],
#  ['<BOS>', '我', '离', '婚', '了', '<EOS>'],
#  ['<BOS>', '我', '很', '难', '过', '<EOS>'],
#  ['<BOS>', '我', '同', '意', '它', '<EOS>'],
#  ['<BOS>', '我', '相', '信', '你', '<EOS>'],
#  ['<BOS>', '我', '信', '过', '你', '<EOS>'],
#  ['<BOS>', '我', '看', '得', '见', '汤', '姆', '<EOS>'],
#  ['<BOS>', '我', '無', '法', '做', '到', '這', '一', '點', '<EOS>'],
#  ['<BOS>', '我', '鄙', '视', '你', '<EOS>'],
#  ['<BOS>', '我', '做', '得', '好', '到', '不', '能', '再', '好', '了', '<EOS>'],
#  ['<BOS>', '我', '确', '实', '看', '见', '他', '了', '<EOS>'],
#  ['<BOS>', '我', '没', '通', '过', '<EOS>'],
#  ['<BOS>', '我', '觉', '得', '很', '孤', '独', '<EOS>'],
#  ['<BOS>', '我', '是', '免', '費', '得', '到', '的', '<EOS>'],
#  ['<BOS>', '我', '有', '一', '个', '家', '<EOS>'],
#  ['<BOS>', '我', '有', '一', '只', '蛋', '<EOS>'],
#  ['<BOS>', '我', '必', '须', '赢', '<EOS>'],
#  ['<BOS>', '我', '喜', '歡', '運', '動', '<EOS>'],
#  ['<BOS>', '我', '喜', '歡', '甜', '食', '<EOS>'],
#  ['<BOS>', '我', '喜', '歡', '吃', '<EOS>'],
#  ['<BOS>', '我', '喜', '欢', '跑', '步', '<EOS>'],
#  ['<BOS>', '我', '愛', '咖', '啡', '<EOS>'],
#  ['<BOS>', '我', '愛', '電', '影', '<EOS>'],
#  ['<BOS>', '我', '愛', '大', '自', '然', '<EOS>'],
#  ['<BOS>', '我', '喜', '歡', '運', '動', '<EOS>'],
#  ['<BOS>', '我', '想', '念', '波', '士', '頓', '<EOS>'],
#  ['<BOS>', '我', '現', '在', '必', '須', '走', '了', '<EOS>'],
#  ['<BOS>', '我', '需', '要', '尝', '试', '<EOS>'],
#  ['<BOS>', '我', '尊', '敬', '湯', '姆', '<EOS>'],
#  ['<BOS>', '我', '想', '我', '可', '以', '<EOS>'],
#  ['<BOS>', '我', '用', '<EOS>'],
#  ['<BOS>', '我', '想', '哭', '<EOS>'],
#  ['<BOS>', '我', '想', '死', '<EOS>'],
#  ['<BOS>', '我', '刚', '才', '在', '家', '<EOS>'],
#  ['<BOS>', '我', '很', '冷', '<EOS>'],
#  ['<BOS>', '我', '要', '買', '這', '個', '<EOS>'],
#  ['<BOS>', '我', '会', '打', '电', '话', '给', '你', '<EOS>'],
#  ['<BOS>', '我', '會', '在', '這', '裡', '吃', '飯', '<EOS>'],
#  ['<BOS>', '我', '会', '去', '接', '他', '的', '<EOS>'],
#  ['<BOS>', '我', '是', '個', '老', '師', '<EOS>'],
#  ['<BOS>', '我', '累', '死', '了', '<EOS>'],
#  ['<BOS>', '困', '死', '了', '<EOS>'],
#  ['<BOS>', '我', '在', '節', '食', '<EOS>'],
#  ['<BOS>', '我', '这', '就', '上', '路', '<EOS>'],
#  ['<BOS>', '我', '真', '蠢', '<EOS>'],
#  ['<BOS>', '我', '很', '忙', '<EOS>'],
#  ['<BOS>', '我', '有', '时', '间', '<EOS>'],
#  ['<BOS>', '我', '有', '酒', '<EOS>'],
#  ['<BOS>', '严', '重', '吗', '<EOS>'],
#  ['<BOS>', '下', '雨', '了', '<EOS>'],
#  ['<BOS>', '在', '下', '雨', '<EOS>'],
#  ['<BOS>', '看', '起', '来', '不', '错', '<EOS>'],
#  ['<BOS>', '可', '能', '会', '下', '雨', '<EOS>'],
#  ['<BOS>', '可', '能', '要', '下', '雨', '了', '<EOS>'],
#  ['<BOS>', '它', '是', '個', '秘', '密', '<EOS>'],
#  ['<BOS>', '公', '事', '公', '辦', '<EOS>'],
#  ['<BOS>', '天', '氣', '好', '冷', '<EOS>'],
#  ['<BOS>', '它', '有', '改', '善', '了', '<EOS>'],
#  ['<BOS>', '我', '請', '客', '<EOS>'],
#  ['<BOS>', '不', '是', '我', '的', '<EOS>'],
#  ['<BOS>', '它', '太', '長', '了', '<EOS>'],
#  ['<BOS>', '它', '太', '大', '聲', '<EOS>'],
#  ['<BOS>', '它', '很', '大', '<EOS>'],
#  ['<BOS>', '确', '保', '汤', '姆', '安', '全', '<EOS>'],
#  ['<BOS>', '保', '持', '安', '静', '<EOS>'],
#  ['<BOS>', '讓', '我', '看', '看', '<EOS>'],
#  ['<BOS>', '鎖', '大', '門', '<EOS>'],
#  ['<BOS>', '我', '可', '以', '進', '來', '嗎', '<EOS>'],
#  ['<BOS>', '在', '那', '裡', '見', '我', '<EOS>'],
#  ['<BOS>', '我', '的', '脚', '痛', '<EOS>'],
#  ['<BOS>', '我', '的', '钢', '笔', '是', '新', '的', '<EOS>'],
#  ['<BOS>', '决', '不', '放', '弃', '<EOS>'],
#  ['<BOS>', '量', '力', '而', '行', '<EOS>'],
#  ['<BOS>', '戒', '掉', '赌', '博', '吧', '<EOS>'],
#  ['<BOS>', '现', '在', '读', '这', '个', '<EOS>'],
#  ['<BOS>', '拯', '救', '你', '自', '己', '<EOS>'],
#  ['<BOS>', '再', '见', '<EOS>'],
#  ['<BOS>', '再', '见', '<EOS>'],
#  ['<BOS>', '和', '我', '握', '手', '<EOS>'],
#  ['<BOS>', '我', '们', '该', '步', '行', '吗', '<EOS>'],
#  ['<BOS>', '她', '感', '到', '闷', '闷', '不', '乐', '的', '<EOS>'],
#  ['<BOS>', '她', '恨', '他', '<EOS>'],
#  ['<BOS>', '她', '愛', '湯', '姆', '<EOS>'],
#  ['<BOS>', '她', '在', '节', '食', '中', '<EOS>'],
#  ['<BOS>', '她', '是', '我', '的', '菜', '<EOS>'],
#  ['<BOS>', '不', '要', '把', '门', '开', '着', '<EOS>'],
#  ['<BOS>', '关', '门', '<EOS>'],
#  ['<BOS>', '坐', '我', '旁', '边', '<EOS>'],
#  ['<BOS>', '講', '清', '楚', '<EOS>'],
#  ['<BOS>', '搅', '一', '下', '汤', '<EOS>'],
#  ['<BOS>', '别', '再', '插', '手', '<EOS>'],
#  ['<BOS>', '停', '止', '射', '击', '<EOS>'],
#  ['<BOS>', '改', '邪', '归', '正', '<EOS>'],
#  ['<BOS>', '事', '情', '难', '免', '会', '发', '生', '<EOS>'],
#  ['<BOS>', '重', '新', '告', '訴', '我', '<EOS>'],
#  ['<BOS>', '还', '是', '要', '说', '谢', '谢', '的', '<EOS>'],
#  ['<BOS>', '那', '是', '一', '本', '書', '<EOS>'],
#  ['<BOS>', '铃', '响', '了', '<EOS>'],
#  ['<BOS>', '他', '們', '有', '帶', '武', '器', '<EOS>'],
#  ['<BOS>', '这', '是', '假', '发', '<EOS>'],
#  ['<BOS>', '时', '间', '就', '是', '金', '钱', '<EOS>'],
#  ['<BOS>', '今', '天', '很', '有', '趣', '<EOS>'],
#  ['<BOS>', '汤', '姆', '没', '走', '<EOS>'],
#  ['<BOS>', '汤', '姆', '是', '个', '乡', '巴', '佬', '<EOS>'],
#  ['<BOS>', '湯', '姆', '缺', '席', '<EOS>'],
#  ['<BOS>', '汤', '姆', '是', '个', '无', '聊', '的', '人', '<EOS>'],
#  ['<BOS>', '汤', '姆', '非', '常', '性', '感', '<EOS>'],
#  ['<BOS>', '湯', '姆', '不', '老', '<EOS>'],
#  ['<BOS>', '湯', '姆', '認', '識', '他', '<EOS>'],
#  ['<BOS>', '汤', '姆', '爱', '你', '<EOS>'],
#  ['<BOS>', '汤', '姆', '睡', '过', '头', '了', '<EOS>'],
#  ['<BOS>', '汤', '姆', '跑', '得', '快', '<EOS>'],
#  ['<BOS>', '湯', '姆', '被', '解', '僱', '了', '<EOS>'],
#  ['<BOS>', '請', '稍', '等', '<EOS>'],
#  ['<BOS>', '我', '们', '保', '持', '了', '沉', '默', '<EOS>'],
#  ['<BOS>', '我', '們', '喜', '歡', '音', '樂', '<EOS>'],
#  ['<BOS>', '我', '們', '想', '你', '<EOS>'],
#  ['<BOS>', '我', '們', '需', '要', '錢', '<EOS>'],
#  ['<BOS>', '我', '们', '明', '白', '<EOS>'],
#  ['<BOS>', '我', '們', '想', '要', '糖', '<EOS>'],
#  ['<BOS>', '我', '們', '會', '很', '忙', '<EOS>'],
#  ['<BOS>', '我', '們', '會', '去', '做', '<EOS>'],
#  ['<BOS>', '我', '們', '已', '經', '到', '了', '<EOS>'],
#  ['<BOS>', '你', '在', '哪', '儿', '<EOS>'],
#  ['<BOS>', '玛', '丽', '在', '哪', '里', '<EOS>'],
#  ['<BOS>', '谁', '帮', '帮', '她', '<EOS>'],
#  ['<BOS>', '这', '是', '谁', '的', '<EOS>'],
#  ['<BOS>', '为', '什', '么', '责', '备', '汤', '姆', '<EOS>'],
#  ['<BOS>', '你', '在', '撒', '谎', '<EOS>'],
#  ['<BOS>', '你', '很', '聰', '明', '<EOS>'],
#  ['<BOS>', '你', '能', '跑', '<EOS>'],
#  ['<BOS>', '你', '看', '起', '來', '很', '蒼', '白', '<EOS>'],
#  ['<BOS>', '你', '應', '該', '去', '<EOS>'],
#  ['<BOS>', '你', '最', '好', '去', '<EOS>'],
#  ['<BOS>', '你', '會', '失', '敗', '<EOS>'],
#  ['<BOS>', '你', '工', '作', '努', '力', '<EOS>'],
#  ['<BOS>', '你', '在', '開', '玩', '笑', '吧', '<EOS>'],
#  ['<BOS>', '你', '真', '壞', '<EOS>'],
#  ['<BOS>', '鸟', '会', '飞', '<EOS>'],
#  ['<BOS>', '請', '允', '許', '我', '去', '<EOS>'],
#  ['<BOS>', '你', '在', '哭', '嗎', '<EOS>'],
#  ['<BOS>', '你', '不', '是', '湯', '姆', '嗎', '<EOS>'],
#  ['<BOS>', '你', '不', '是', '湯', '姆', '嗎', '<EOS>'],
#  ['<BOS>', '你', '不', '热', '吗', '<EOS>'],
#  ['<BOS>', '对', '她', '好', '点', '<EOS>'],
#  ['<BOS>', '鳥', '下', '蛋', '<EOS>'],
#  ['<BOS>', '把', '水', '燒', '開', '<EOS>'],
#  ['<BOS>', '把', '它', '带', '给', '我', '<EOS>'],
#  ['<BOS>', '我', '可', '以', '吃', '这', '个', '吗', '<EOS>'],
#  ['<BOS>', '我', '能', '幫', '你', '嗎', '<EOS>'],
#  ['<BOS>', '我', '能', '坐', '这', '里', '吗', '<EOS>'],
#  ['<BOS>', '打', '掃', '房', '間', '<EOS>'],
#  ['<BOS>', '关', '门', '<EOS>'],
#  ['<BOS>', '我', '要', '咖', '啡', '谢', '谢', '<EOS>'],
#  ['<BOS>', '解', '决', '他', '们', '<EOS>'],
#  ['<BOS>', '我', '们', '认', '识', '你', '么', '<EOS>'],
#  ['<BOS>', '你', '认', '识', '我', '吗', '<EOS>'],
#  ['<BOS>', '你', '还', '认', '识', '我', '吗', '<EOS>'],
#  ['<BOS>', '你', '喜', '欢', '吗', '<EOS>'],
#  ['<BOS>', '你', '喜', '歡', '嗎', '<EOS>'],
#  ['<BOS>', '你', '想', '我', '了', '<EOS>'],
#  ['<BOS>', '你', '想', '我', '吗', '<EOS>'],
#  ['<BOS>', '你', '保', '证', '吗', '<EOS>'],
#  ['<BOS>', '別', '碰', '它', '<EOS>'],
#  ['<BOS>', '每', '个', '人', '都', '会', '说', '谎', '<EOS>'],
#  ['<BOS>', '狐', '狸', '吃', '母', '鸡', '<EOS>'],
#  ['<BOS>', '起', '床', '<EOS>'],
#  ['<BOS>', '下', '午', '好', '<EOS>'],
#  ['<BOS>', '新', '年', '快', '樂', '<EOS>'],
#  ['<BOS>', '你', '該', '多', '吃', '點', '<EOS>'],
#  ['<BOS>', '他', '提', '速', '了', '<EOS>'],
#  ['<BOS>', '他', '不', '會', '游', '泳', '<EOS>'],
#  ['<BOS>', '他', '把', '我', '們', '弄', '糊', '塗', '了', '<EOS>'],
#  ['<BOS>', '他', '不', '说', '谎', '<EOS>'],
#  ['<BOS>', '他', '是', '美', '国', '人', '<EOS>'],
#  ['<BOS>', '他', '一', '个', '人', '生', '活', '<EOS>'],
#  ['<BOS>', '他', '独', '自', '生', '活', '<EOS>'],
#  ['<BOS>', '他', '看', '起', '来', '很', '年', '轻', '<EOS>'],
#  ['<BOS>', '他', '弄', '丟', '了', '一', '本', '書', '<EOS>'],
#  ['<BOS>', '他', '唱', '了', '一', '首', '歌', '<EOS>'],
#  ['<BOS>', '他', '被', '淹', '死', '了', '<EOS>'],
#  ['<BOS>', '他', '溺', '水', '而', '亡', '<EOS>'],
#  ['<BOS>', '他', '是', '個', '大', '男', '孩', '<EOS>'],
#  ['<BOS>', '他', '是', '作', '家', '<EOS>'],
#  ['<BOS>', '這', '裡', '有', '一', '本', '書', '<EOS>'],
#  ['<BOS>', '它', '多', '貴', '<EOS>'],
#  ['<BOS>', '多', '少', '錢', '<EOS>'],
#  ['<BOS>', '你', '們', '好', '嗎', '<EOS>'],
#  ['<BOS>', '我', '是', '匈', '牙', '利', '人', '<EOS>'],
#  ['<BOS>', '我', '是', '個', '老', '師', '<EOS>'],
#  ['<BOS>', '我', '累', '死', '了', '<EOS>'],
#  ['<BOS>', '我', '今', '天', '休', '息', '<EOS>'],
#  ['<BOS>', '我', '太', '矮', '了', '<EOS>'],
#  ['<BOS>', '我', '借', '錢', '<EOS>'],
#  ['<BOS>', '我', '的', '手', '臂', '斷', '了', '<EOS>'],
#  ['<BOS>', '我', '不', '懂', '<EOS>'],
#  ['<BOS>', '我', '去', '学', '校', '<EOS>'],
#  ['<BOS>', '我', '被', '逮', '捕', '了', '<EOS>'],
#  ['<BOS>', '我', '起', '床', '早', '<EOS>'],
#  ['<BOS>', '我', '有', '一', '个', '设', '想', '<EOS>'],
#  ['<BOS>', '我', '有', '一', '个', '愿', '景', '<EOS>'],
#  ['<BOS>', '我', '讨', '厌', '星', '期', '一', '<EOS>'],
#  ['<BOS>', '我', '咳', '嗽', '<EOS>'],
#  ['<BOS>', '我', '有', '一', '个', '梦', '想', '<EOS>'],
#  ['<BOS>', '我', '打', '嗝', '了', '<EOS>'],
#  ['<BOS>', '我', '没', '时', '间', '<EOS>'],
#  ['<BOS>', '我', '经', '常', '打', '嗝', '<EOS>'],
#  ['<BOS>', '我', '喜', '歡', '花', '<EOS>'],
#  ['<BOS>', '我', '喜', '欢', '跑', '步', '<EOS>'],
#  ['<BOS>', '我', '喜', '欢', '阅', '读', '<EOS>'],
#  ['<BOS>', '我', '喜', '欢', '跑', '步', '<EOS>'],
#  ['<BOS>', '我', '喜', '欢', '阅', '读', '<EOS>'],
#  ['<BOS>', '我', '爱', '我', '的', '生', '活', '<EOS>'],
#  ['<BOS>', '我', '爱', '我', '的', '生', '命', '<EOS>'],
#  ['<BOS>', '我', '爱', '我', '的', '妻', '子', '<EOS>'],
#  ['<BOS>', '我', '愛', '派', '對', '<EOS>'],
#  ['<BOS>', '我', '遇', '见', '一', '个', '朋', '友', '<EOS>'],
#  ['<BOS>', '我', '需', '要', '一', '張', '郵', '票', '<EOS>'],
#  ['<BOS>', '我', '尽', '快', '需', '要', '<EOS>'],
#  ['<BOS>', '我', '需', '要', '我', '的', '大', '衣', '<EOS>'],
#  ['<BOS>', '我', '需', '要', '知', '道', '<EOS>'],
#  ['<BOS>', '我', '经', '常', '打', '嗝', '<EOS>'],
#  ['<BOS>', '我', '说', '过', '了', '闭', '嘴', '<EOS>'],
#  ['<BOS>', '我', '看', '到', '了', '五', '個', '男', '人', '<EOS>'],
#  ['<BOS>', '我', '应', '该', '去', '做', '<EOS>'],
#  ['<BOS>', '我', '学', '韩', '语', '<EOS>'],
#  ['<BOS>', '我', '以', '前', '是', '醫', '生', '<EOS>'],
#  ['<BOS>', '我', '在', '學', '習', '<EOS>'],
#  ['<BOS>', '我', '要', '控', '告', '你', '<EOS>'],
#  ['<BOS>', '我', '想', '要', '去', '<EOS>'],
#  ['<BOS>', '我', '会', '警', '告', '汤', '姆', '<EOS>'],
#  ['<BOS>', '我', '会', '回', '来', '的', '<EOS>'],
#  ['<BOS>', '我', '會', '責', '備', '他', '<EOS>'],
#  ['<BOS>', '我', '會', '留', '意', '的', '<EOS>'],
#  ['<BOS>', '由', '我', '来', '做', '<EOS>'],
#  ['<BOS>', '我', '會', '待', '在', '家', '裡', '<EOS>'],
#  ['<BOS>', '我', '請', '你', '<EOS>'],
#  ['<BOS>', '我', '是', '一', '個', '自', '由', '的', '人', '<EOS>'],
#  ['<BOS>', '我', '是', '一', '个', '好', '人', '<EOS>'],
#  ['<BOS>', '我', '在', '他', '後', '面', '<EOS>'],
#  ['<BOS>', '我', '今', '天', '有', '空', '<EOS>'],
#  ['<BOS>', '我', '来', '自', '东', '京', '<EOS>'],
#  ['<BOS>', '我', '不', '貪', '婪', '<EOS>'],
#  ['<BOS>', '我', '没', '有', '罪', '<EOS>'],
#  ['<BOS>', '我', '很', '激', '动', '<EOS>'],
#  ['<BOS>', '我', '脱', '衣', '服', '<EOS>'],
#  ['<BOS>', '我', '很', '快', '樂', '<EOS>'],
#  ['<BOS>', '我', '很', '快', '乐', '<EOS>'],
#  ['<BOS>', '我', '見', '過', '<EOS>'],
#  ['<BOS>', '他', '是', '日', '本', '人', '吗', '<EOS>'],
#  ['<BOS>', '那', '更', '好', '吗', '<EOS>'],
#  ['<BOS>', '它', '不', '是', '黑', '色', '的', '嗎', '<EOS>'],
#  ['<BOS>', '太', '早', '了', '<EOS>'],
#  ['<BOS>', '太', '晚', '了', '<EOS>'],
#  ['<BOS>', '那', '样', '说', '得', '通', '<EOS>'],
#  ['<BOS>', '它', '花', '了', '几', '个', '月', '<EOS>'],
#  ['<BOS>', '这', '是', '全', '新', '的', '<EOS>'],
#  ['<BOS>', '它', '是', '危', '險', '的', '<EOS>'],
#  ['<BOS>', '这', '不', '好', '笑', '<EOS>'],
#  ['<BOS>', '它', '是', '我', '們', '的', '錯', '誤', '<EOS>'],
#  ['<BOS>', '这', '是', '事', '实', '<EOS>'],
#  ['<BOS>', '它', '太', '大', '了', '<EOS>'],
#  ['<BOS>', '这', '就', '要', '看', '您', '了', '<EOS>'],
#  ['<BOS>', '由', '你', '來', '決', '定', '<EOS>'],
#  ['<BOS>', '非', '常', '冷', '<EOS>'],
#  ['<BOS>', '做', '得', '很', '好', '<EOS>'],
#  ['<BOS>', '它', '是', '你', '的', '書', '<EOS>'],
#  ['<BOS>', '該', '你', '走', '了', '<EOS>'],
#  ['<BOS>', '继', '续', '听', '<EOS>'],
#  ['<BOS>', '让', '我', '去', '做', '<EOS>'],
#  ['<BOS>', '让', '我', '们', '回', '家', '吧', '<EOS>'],
#  ['<BOS>', '我', '們', '吃', '吧', '<EOS>'],
#  ['<BOS>', '聽', '聽', '這', '個', '<EOS>'],
#  ['<BOS>', '我', '可', '以', '用', '嗎', '<EOS>'],
#  ['<BOS>', '我', '叫', '<EOS>'],
#  ['<BOS>', '现', '在', '我', '想', '起', '来', '了', '<EOS>'],
#  ['<BOS>', '請', '進', '來', '<EOS>'],
#  ['<BOS>', '麻', '煩', '您', '那', '樣', '做', '<EOS>'],
#  ['<BOS>', '請', '幫', '助', '我', '<EOS>'],
#  ['<BOS>', '請', '幫', '我', '<EOS>'],
#  ['<BOS>', '請', '加', '入', '我', '們', '<EOS>'],
#  ['<BOS>', '請', '告', '訴', '我', '<EOS>'],
#  ['<BOS>', '请', '清', '洗', '它', '<EOS>'],
#  ['<BOS>', '物', '價', '上', '漲', '<EOS>'],
#  ['<BOS>', '看', '这', '本', '书', '<EOS>'],
#  ['<BOS>', '說', '清', '楚', '<EOS>'],
#  ['<BOS>', '科', '學', '好', '玩', '<EOS>'],
#  ['<BOS>', '再', '见', '<EOS>'],
#  ['<BOS>', '她', '愚', '弄', '了', '他', '<EOS>'],
#  ['<BOS>', '她', '種', '了', '玫', '瑰', '<EOS>'],
#  ['<BOS>', '她', '也', '許', '會', '來', '<EOS>'],
#  ['<BOS>', '她', '看', '來', '有', '錢', '<EOS>'],
#  ['<BOS>', '烟', '雾', '出', '现', '了', '<EOS>'],
#  ['<BOS>', '有', '人', '打', '電', '話', '來', '<EOS>'],
#  ['<BOS>', '停', '止', '发', '牢', '骚', '吧', '<EOS>'],
#  ['<BOS>', '停', '止', '抵', '抗', '<EOS>'],
#  ['<BOS>', '你', '可', '以', '慢', '慢', '来', '<EOS>'],
#  ['<BOS>', '那', '是', '一', '個', '恥', '辱', '<EOS>'],
#  ['<BOS>', '那', '是', '我', '的', '大', '衣', '<EOS>'],
#  ['<BOS>', '那', '是', '完', '美', '的', '<EOS>'],
#  ['<BOS>', '多', '遗', '憾', '啊', '<EOS>'],
#  ['<BOS>', '那', '太', '糟', '糕', '了', '<EOS>'],
#  ['<BOS>', '鳥', '兒', '歌', '唱', '<EOS>'],
#  ['<BOS>', '旗', '子', '升', '起', '了', '<EOS>'],
#  ['<BOS>', '電', '話', '正', '在', '響', '<EOS>'],
#  ['<BOS>', '他', '們', '目', '光', '相', '接', '<EOS>'],
#  ['<BOS>', '這', '些', '是', '筆', '<EOS>'],
#  ['<BOS>', '他', '們', '恨', '湯', '姆', '<EOS>'],
#  ['<BOS>', '他', '們', '有', '工', '作', '<EOS>'],
#  ['<BOS>', '他', '們', '讓', '我', '走', '<EOS>'],
#  ['<BOS>', '他', '们', '喜', '欢', '那', '个', '<EOS>'],
#  ['<BOS>', '他', '们', '信', '任', '汤', '姆', '<EOS>'],
#  ['<BOS>', '他', '們', '想', '要', '更', '多', '<EOS>'],
#  ['<BOS>', '他', '們', '想', '要', '這', '個', '<EOS>'],
#  ['<BOS>', '他', '们', '不', '错', '<EOS>'],
#  ['<BOS>', '这', '是', '一', '本', '书', '<EOS>'],
#  ['<BOS>', '那', '是', '我', '的', '包', '<EOS>'],
#  ['<BOS>', '湯', '姆', '能', '改', '變', '<EOS>'],
#  ['<BOS>', '汤', '姆', '不', '会', '游', '泳', '<EOS>'],
#  ['<BOS>', '湯', '姆', '有', '個', '計', '畫', '<EOS>'],
#  ['<BOS>', '汤', '姆', '是', '个', '拉', '比', '<EOS>'],
#  ['<BOS>', '汤', '姆', '不', '傻', '<EOS>'],
#  ['<BOS>', '湯', '姆', '看', '起', '來', '很', '蒼', '白', '<EOS>'],
#  ['<BOS>', '湯', '姆', '走', '了', '出', '去', '<EOS>'],
#  ['<BOS>', '汤', '姆', '无', '所', '畏', '惧', '<EOS>'],
#  ['<BOS>', '汤', '姆', '在', '笑', '<EOS>'],
#  ['<BOS>', '汤', '姆', '兴', '奋', '不', '已', '<EOS>'],
#  ['<BOS>', '對', '他', '好', '一', '點', '<EOS>'],
#  ['<BOS>', '开', '电', '视', '<EOS>'],
#  ['<BOS>', '把', '电', '视', '声', '音', '调', '大', '点', '儿', '<EOS>'],
#  ['<BOS>', '汤', '姆', '睡', '着', '了', '吗', '<EOS>'],
#  ['<BOS>', '洗', '您', '的', '脚', '<EOS>'],
#  ['<BOS>', '洗', '你', '的', '脚', '<EOS>'],
#  ['<BOS>', '自', '己', '当', '心', '啊', '<EOS>'],
#  ['<BOS>', '我', '們', '原', '諒', '你', '<EOS>'],
#  ['<BOS>', '我', '們', '誰', '也', '不', '認', '識', '<EOS>'],
#  ['<BOS>', '我', '们', '学', '习', '音', '乐', '<EOS>'],
#  ['<BOS>', '我', '们', '没', '迟', '到', '<EOS>'],
#  ['<BOS>', '好', '吧', '我', '們', '走', '吧', '<EOS>'],
#  ['<BOS>', '你', '是', '对', '的', '吗', '<EOS>'],
#  ['<BOS>', '你', '們', '呢', '<EOS>'],
#  ['<BOS>', '您', '呢', '<EOS>'],
#  ['<BOS>', '你', '的', '職', '業', '是', '什', '麼', '<EOS>'],
#  ['<BOS>', '她', '做', '什', '么', '工', '作', '<EOS>'],
#  ['<BOS>', '我', '们', '去', '哪', '儿', '<EOS>'],
#  ['<BOS>', '之', '前', '你', '在', '哪', '里', '<EOS>'],
#  ['<BOS>', '那', '家', '伙', '是', '谁', '<EOS>'],
#  ['<BOS>', '你', '問', '這', '個', '幹', '什', '麼', '<EOS>'],
#  ['<BOS>', '为', '什', '么', '他', '在', '这', '儿', '<EOS>'],
#  ['<BOS>', '擦', '擦', '你', '的', '眼', '睛', '<EOS>'],
#  ['<BOS>', '是', '的', '我', '知', '道', '<EOS>'],
#  ['<BOS>', '是', '的', '當', '然', '<EOS>'],
#  ['<BOS>', '你', '看', '起', '來', '很', '無', '聊', '<EOS>'],
#  ['<BOS>', '你', '看', '起', '来', '很', '紧', '张', '<EOS>'],
#  ['<BOS>', '你', '看', '起', '來', '很', '疲', '倦', '<EOS>'],
#  ['<BOS>', '你', '必', '須', '去', '做', '<EOS>'],
#  ['<BOS>', '你', '會', '愛', '它', '<EOS>'],
#  ['<BOS>', '你', '開', '玩', '笑', '吧', '<EOS>'],
#  ['<BOS>', '你', '有', '歲', '了', '嗎', '<EOS>'],
#  ['<BOS>', '你', '是', '认', '真', '的', '吗', '<EOS>'],
#  ['<BOS>', '你', '渴', '吗', '<EOS>'],
#  ['<BOS>', '球', '是', '圆', '的', '<EOS>'],
#  ['<BOS>', '为', '我', '感', '到', '高', '兴', '吧', '<EOS>'],
#  ['<BOS>', '规', '矩', '点', '<EOS>'],
#  ['<BOS>', '黑', '色', '很', '衬', '你', '<EOS>'],
#  ['<BOS>', '烧', '一', '点', '水', '<EOS>'],
#  ['<BOS>', '叫', '警', '察', '<EOS>'],
#  ['<BOS>', '报', '警', '<EOS>'],
#  ['<BOS>', '报', '警', '<EOS>'],
#  ['<BOS>', '你', '能', '找', '到', '它', '嗎', '<EOS>'],
#  ['<BOS>', '清', '掃', '你', '的', '房', '間', '<EOS>'],
#  ['<BOS>', '闭', '上', '你', '的', '眼', '睛', '<EOS>'],
#  ['<BOS>', '闭', '上', '你', '们', '的', '眼', '睛', '<EOS>'],
#  ['<BOS>', '如', '果', '你', '能', '就', '來', '吧', '<EOS>'],
#  ['<BOS>', '祝', '贺', '你', '<EOS>'],
#  ['<BOS>', '恭', '喜', '<EOS>'],
#  ['<BOS>', '你', '能', '做', '到', '嗎', '<EOS>'],
#  ['<BOS>', '数', '到', '三', '十', '<EOS>'],
#  ['<BOS>', '汤', '姆', '说', '是', '谁', '了', '吗', '<EOS>'],
#  ['<BOS>', '你', '以', '前', '喜', '欢', '吗', '<EOS>'],
#  ['<BOS>', '你', '想', '我', '了', '<EOS>'],
#  ['<BOS>', '您', '经', '常', '去', '吗', '<EOS>'],
#  ['<BOS>', '你', '有', '嗎', '<EOS>'],
#  ['<BOS>', '你', '认', '识', '他', '吗', '<EOS>'],
#  ['<BOS>', '你', '喜', '欢', '说', '唱', '音', '乐', '吗', '<EOS>'],
#  ['<BOS>', '你', '记', '得', '吗', '<EOS>'],
#  ['<BOS>', '愛', '存', '在', '嗎', '<EOS>'],
#  ['<BOS>', '別', '被', '騙', '了', '<EOS>'],
#  ['<BOS>', '别', '来', '烦', '我', '<EOS>'],
#  ['<BOS>', '別', '忘', '了', '我', '<EOS>'],
#  ['<BOS>', '别', '打', '开', '那', '个', '<EOS>'],
#  ['<BOS>', '不', '要', '冒', '险', '<EOS>'],
#  ['<BOS>', '别', '说', '谎', '<EOS>'],
#  ['<BOS>', '开', '车', '小', '心', '点', '<EOS>'],
#  ['<BOS>', '離', '開', '這', '裡', '<EOS>'],
#  ['<BOS>', '幫', '湯', '姆', '一', '把', '<EOS>'],
#  ['<BOS>', '把', '它', '给', '他', '们', '<EOS>'],
#  ['<BOS>', '去', '露', '台', '<EOS>'],
#  ['<BOS>', '綠', '色', '適', '合', '你', '<EOS>'],
#  ['<BOS>', '祝', '你', '一', '天', '过', '得', '愉', '快', '<EOS>'],
#  ['<BOS>', '他', '行', '动', '迅', '速', '<EOS>'],
#  ['<BOS>', '他', '开', '始', '哭', '了', '<EOS>'],
#  ['<BOS>', '他', '是', '我', '父', '親', '<EOS>'],
#  ['<BOS>', '他', '非', '常', '親', '切', '<EOS>'],
#  ['<BOS>', '他', '很', '高', '<EOS>'],
#  ['<BOS>', '他', '刚', '到', '<EOS>'],
#  ['<BOS>', '他', '看', '起', '來', '很', '強', '壯', '<EOS>'],
#  ['<BOS>', '他', '喜', '歡', '火', '車', '<EOS>'],
#  ['<BOS>', '他', '向', '我', '施', '压', '<EOS>'],
#  ['<BOS>', '他', '努', '力', '學', '習', '<EOS>'],
#  ['<BOS>', '他', '企', '图', '说', '谎', '<EOS>'],
#  ['<BOS>', '他', '很', '容', '易', '觉', '得', '累', '<EOS>'],
#  ['<BOS>', '他', '很', '老', '<EOS>'],
#  ['<BOS>', '他', '會', '倖', '存', '<EOS>'],
#  ['<BOS>', '他', '是', '喜', '剧', '演', '员', '<EOS>'],
#  ['<BOS>', '他', '是', '個', '好', '人', '<EOS>'],
#  ['<BOS>', '他', '是', '個', '好', '人', '<EOS>'],
#  ['<BOS>', '他', '是', '个', '好', '人', '<EOS>'],
#  ['<BOS>', '他', '是', '個', '好', '人', '<EOS>'],
#  ['<BOS>', '他', '是', '一', '个', '高', '大', '的', '男', '孩', '<EOS>'],
#  ['<BOS>', '他', '不', '是', '英', '雄', '<EOS>'],
#  ['<BOS>', '他', '不', '是', '傻', '子', '<EOS>'],
#  ['<BOS>', '他', '非', '常', '生', '气', '<EOS>'],
#  ['<BOS>', '这', '是', '你', '的', '茶', '<EOS>'],
#  ['<BOS>', '嗨', '你', '好', '嗎', '<EOS>'],
#  ['<BOS>', '他', '的', '话', '就', '是', '命', '令', '<EOS>'],
#  ['<BOS>', '你', '感', '觉', '如', '何', '<EOS>'],
#  ['<BOS>', '我', '怎', '麼', '知', '道', '<EOS>'],
#  ['<BOS>', '大', '家', '好', '嗎', '<EOS>'],
#  ['<BOS>', '你', '們', '好', '嗎', '<EOS>'],
#  ['<BOS>', '你', '幾', '歲', '<EOS>'],
#  ['<BOS>', '你', '真', '粗', '魯', '<EOS>'],
#  ['<BOS>', '可', '憐', '<EOS>'],
#  ['<BOS>', '這', '個', '蘋', '果', '怎', '麼', '樣', '<EOS>'],
#  ['<BOS>', '我', '全', '身', '酸', '痛', '<EOS>'],
#  ['<BOS>', '我', '是', '一', '个', '好', '男', '孩', '<EOS>'],
#  ['<BOS>', '我', '是', '从', '中', '国', '来', '的', '<EOS>'],
#  ['<BOS>', '我', '来', '自', '中', '国', '<EOS>'],
#  ['<BOS>', '我', '有', '麻', '煩', '了', '<EOS>'],
#  ['<BOS>', '我', '遇', '到', '困', '難', '了', '<EOS>'],
#  ['<BOS>', '我', '吃', '了', '這', '個', '蘋', '果', '<EOS>'],
#  ['<BOS>', '我', '烤', '了', '曲', '奇', '<EOS>'],
#  ['<BOS>', '我', '開', '始', '跑', '<EOS>'],
#  ['<BOS>', '我', '訂', '了', '一', '個', '位', '子', '<EOS>'],
#  ['<BOS>', '我', '買', '了', '一', '本', '書', '<EOS>'],
#  ['<BOS>', '我', '打', '電', '話', '給', '湯', '姆', '了', '<EOS>'],
#  ['<BOS>', '我', '叫', '她', '起', '来', '<EOS>'],
#  ['<BOS>', '我', '游', '泳', '可', '以', '游', '得', '很', '好', '<EOS>'],
#  ['<BOS>', '我', '看', '不', '見', '你', '<EOS>'],
#  ['<BOS>', '我', '不', '能', '取', '消', '它', '<EOS>'],
#  ['<BOS>', '我', '不', '要', '<EOS>'],
#  ['<BOS>', '我', '感', '觉', '轻', '松', '了', '<EOS>'],
#  ['<BOS>', '我', '六', '點', '起', '床', '<EOS>'],
#  ['<BOS>', '那', '时', '我', '没', '有', '选', '择', '的', '余', '地', '<EOS>'],
#  ['<BOS>', '我', '讨', '厌', '学', '习', '<EOS>'],
#  ...]

# %%
class Vocabulary:
    def __init__(self, vocab):
        self.vocab = vocab

    @classmethod
    def from_documents(cls, documents):
        tokens = set() 
        for cmt in documents:
            tokens.update(list(cmt))
        tokens = ["<PAD>", "<UNK>", "<BOS>", "<EOS>"] + sorted(list(tokens)) # set是无序的，可以在list之后做排序,保证每次构建词典顺序一致
        vocab = {token:i for i, token in enumerate(tokens)} 
        return cls(vocab)

# %%
enc_vocab = Vocabulary.from_documents(enc_data)
dec_vocab = Vocabulary.from_documents(dec_data)
print(len(enc_vocab.vocab))
print(len(dec_vocab.vocab))
# Out:
# 6952
# 3330

# %%
# 编码-解码 样本

# 能getitem，能len，不就是dataset吗

# def batch_fn(data):
#     "自己编写的"
#     enc_list, dec_lsit = [], []
#     for enc, dec in data:
#         enc_index = [enc_vocab.vocab.get(tk, 1) for tk in enc]
#         dec_index = [dec_vocab.vocab.get(tk, 1) for tk in dec]
#         enc_tensor = torch.zeros(size=(1000, ), dtype=torch.long)
#         dec_tensor = torch.zeros(size=(1000, ), dtype=torch.long)

#         for i in range(len(enc_index)):
#             enc_tensor[i] = enc_index[i]
#         enc_list.append(enc_tensor)

#         for i in range(len(dec_index)):
#             dec_tensor[i] = dec_index[i]
#         dec_lsit.append(dec_tensor)

#     enc_input = torch.stack(enc_list, dim=0)
#     dec_input = torch.stack(dec_lsit, dim=0)
#     return enc_input,dec_input

#     pass

def batch_fn(data):
    enc_list, dec_lsit = [], []
    for enc, dec in data:
        enc_index = [enc_vocab.vocab.get(tk, 1) for tk in enc]
        dec_index = [dec_vocab.vocab.get(tk, 1) for tk in dec]
        enc_list.append(torch.tensor(enc_index, dtype=torch.long))
        dec_lsit.append(torch.tensor(dec_index, dtype=torch.long))

    # 用批次中最长的序列长度作为最大长度 ： (batch_size ,max_token_len)
    # 把元素为张量的List转换为张量矩阵，自动填充
    enc_input = pad_sequence(enc_list, batch_first=True)
    dec_input = pad_sequence(dec_lsit, batch_first=True)
    return enc_input, dec_input
    pass



dataset = list(zip(enc_data, dec_data))
dataloader = DataLoader(dataset, batch_size=2,shuffle=True, collate_fn=batch_fn)
for enc_input, dec_input in dataloader:
    print(enc_input.shape)
    print(enc_input)
    print(dec_input.shape)
    print(dec_input)
    break
# Out:
# torch.Size([2, 6])
# tensor([[ 586, 2698, 5231, 3698, 1641, 3256],
#         [1124, 2792, 4278, 5600,    0,    0]])
# torch.Size([2, 8])
# tensor([[2788,  298, 1112, 1589, 2619,  285,   91,  148],
#         [2871, 1592, 1392,  104,  137, 1070,   40,    0]])
